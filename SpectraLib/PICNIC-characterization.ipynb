# %%
import os, sys
import numpy as np
sys.path.append(os.path.dirname('/home/lschmidt/repos/mroi_sw/SpectraLib/'))

# %load_ext autoreload

# %autoreload 2

# %%
import detector as D
import matplotlib.pyplot as plt

# %%
time, data = D.readPICNIC('ffbg.fits')
time2, data2 = D.readPICNIC('beam1.fits')

# %%
q1_01, q2_01, q3_01, q4_01 = D.splitQuads(data[1])
q1_02, q2_02, q3_02, q4_02 = D.splitQuads(data[2])
q1_11, q2_11, q3_11, q4_11 = D.splitQuads(data2[1])
q1_12, q2_12, q3_12, q4_12 = D.splitQuads(data2[2])

# %%
np.shape(data)
# Out:
# (100, 256, 256)

# %%
D.plotFrame(data2[0])

# %%
D.plotQuads(q1_11,q2_11,q3_11,q4_11)

# %%
D.plotHist(data[0])

# %%
mask = D.pixelMask(data[0], 10.0, data[0], 10.0)
# Out:
# detector.py:227: RuntimeWarning: invalid value encountered in divide
#   mask = np.nan_to_num((dark1/time1)/(dark2/time2))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-4ff17ce0ee5c> in <module>()
# ----> 1 mask = D.pixelMask(data[0], 10.0, data[0], 10.0)
#
# /home/lschmidt/repos/mroi_sw/SpectraLib/detector.py in pixelMask(dark1, time1, dark2, time2)
#     226     """
#     227     mask = np.nan_to_num((dark1/time1)/(dark2/time2))
# --> 228     plotFrame(mask)
#     229     plotHist(mask, title='Pixel Mask', log=True)
#     230     return mask
#
# /home/lschmidt/repos/mroi_sw/SpectraLib/detector.py in plotFrame(frame)
#     189     img = plt.imshow(frame, interpolation="nearest", cmap=cmap, vmin=0, vmax=maxval)
#     190     plt.title('Frame')
# --> 191     plt.colorbar(spacing='uniform')
#     192     plt.gca().invert_yaxis()
#     193     plt.show()
#
# ...

# %%
D.readNoise(data[0],data[1] , 2.3)
# Out:
# Read Noise:  16.9872524222 e-

# %%
D.conversionGainFrame([q1_01, q1_02, q1_11, q1_12], 1)
# Out:
# means: [  879.54376221  1985.02484131]
# variances:  [  97.91873303  162.47766754]
# e-/ADU = 0.0583989502219

# %%
h200s01 = D.readH2RG('inversegain00s01.fit')
h200s02 = D.readH2RG('inversegain00s02.fit')
h205s01 = D.readH2RG('inversegain05s01.fit')
h205s02 = D.readH2RG('inversegain05s02.fit')
h210s01 = D.readH2RG('inversegain10s01.fit')
h210s02 = D.readH2RG('inversegain10s02.fit')
h220s01 = D.readH2RG('inversegain20s01.fit')
h220s02 = D.readH2RG('inversegain20s02.fit')
h240s01 = D.readH2RG('inversegain40s01.fit')
h240s02 = D.readH2RG('inversegain40s02.fit')

# %%
ch = 15
D.conversionGainFrame([h205s01[:,ch*64:ch*64+64],h205s02[:,ch*64:ch*64+64],h210s01[:,ch*64:ch*64+64],h210s02[:,ch*64:ch*64+64],h220s01[:,ch*64:ch*64+64],h220s02[:,ch*64:ch*64+64],h240s01[:,ch*64:ch*64+64],h240s02[:,ch*64:ch*64+64]], ch)
# Out:
# means: [  8325.7421875  13408.34375    22350.5390625  39074.671875 ]
# variances:  [ 13139.015625    13897.61035156  17676.796875    22934.390625  ]
# [  3.30380369e-01   1.00434036e+04]
# y intercept 10043.4035766
# e-/ADU = 3.02681422524
